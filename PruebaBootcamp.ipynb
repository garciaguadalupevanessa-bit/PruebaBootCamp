# %% [markdown]
# <a href="https://colab.research.google.com/github/garciaguadalupevanessa-bit/PruebaBootCamp/blob/main/PruebaBootcamp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hola Mundo")
# Out:
# Hola Mundo
